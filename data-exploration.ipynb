# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("artermiloff/steam-games-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Evang\.cache\kagglehub\datasets\artermiloff\steam-games-dataset\versions\2

# %%
import pandas as pd

# %%
games = pd.read_csv(f"{path}/games_march2025_cleaned.csv")

# %%
games
# Out:
#          appid                             name release_date  required_age  \
# 0          730                 Counter-Strike 2   2012-08-21             0
# 1       578080              PUBG: BATTLEGROUNDS   2017-12-21             0
# 2          570                           Dota 2   2013-07-09             0
# 3       271590        Grand Theft Auto V Legacy   2015-04-13            17
# 4       359550  Tom Clancy's Rainbow Six® Siege   2015-12-01            17
# ...        ...                              ...          ...           ...
# 89613  2115110                      Outrun Them   2024-02-29             0
# 89614  1174200      Lands of Pharaoh: Episode 1   2020-01-07             0
# 89615  1160190                       Player One   2019-10-10             0
# 89616  3380340                       DragonRoad   2025-01-25             0
# 89617   763730               Ragtag Adventurers   2018-03-01             0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = plt.axes()
sns.heatmap(games.isna().transpose(), cbar=False, ax=ax)

plt.xlabel("Columns")
plt.ylabel("Missing Values")

plt.show()

# %%
(
    games
    .to_csv("games_cleaned.csv", index=False)
)
